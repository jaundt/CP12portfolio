# %% [markdown]
# # 1.EXT.1 — Fundamentals Refresher
#
# This is a fast pass, not first-time teaching — one reminder, one example, one quick check per concept. If something here feels genuinely shaky rather than just a little rusty, flag it to your teacher; that's exactly what this diagnostic is for. Same adventure-game world as everyone else — you'll be building the same kind of game, just at a faster pace and a higher bar.

# %% [markdown]
# ## Quick Recall: Variables &amp; Data Types
#
# Four types you'll use constantly: `str` (quoted text), `int` (whole number), `float` (decimal), `bool` (`True`/`False`, capitalized, no quotes). Python infers the type from the value — check any variable's type with `type()`.

# %%
# Example
character_name = "Zara"
health = 100
damage_multiplier = 1.5
is_alive = True
print(character_name, health, damage_multiplier, is_alive)

# %% [markdown]
# **Quick check:** create one variable of each type describing a weapon (name, damage, weight, is_magical), then print `type()` of each.

# %%
WPname = "brass knuckles"
damage = 7
weight = 0.4
is_magical = False
print(WPname, damage, weight, is_magical)
# Out:
# brass knuckles 7 0.4 False

# %% [markdown]
# ## Quick Recall: Input/Output &amp; f-strings
#
# `input("prompt")` always returns a `str` — wrap it in `int()`/`float()` for numbers. f-strings drop variables into text: `f"Hello, {name}!"`.

# %%
# Example
player_name = input("Name? ")
gold = int(input("Starting gold? "))
print(f"Welcome, {player_name} — you begin with {gold} gold.")

# %% [markdown]
# **Quick check:** ask the player for a weapon name and its damage (as a number), then print both in one f-string line.

# %%
wpn_name = input("Weapon name? ")
wpn_damage = int(input("Weapon damage? "))
print(f'your weapon name is {wpn_name} and it has a damage stat of {wpn_damage}.')

# %% [markdown]
# ## Quick Recall: Operators &amp; Expressions
#
# `+ - * /` as expected; `//` floor-divides (drops the remainder), `%` gives just the remainder, `**` is exponent. Comparisons (`== != < > <= >=`) give back a `bool`.

# %%
# Example
attack = 22
defense = 7
damage_dealt = attack - defense
print(damage_dealt, damage_dealt > 10)
# Out:
# 15 True

# %% [markdown]
# **Quick check:** given `total_potions = 23` shared between `4` people, print how many whole potions each person gets and how many are left over.

# %%
total_potions = 23
potioneach = total_potions // 4
print (f'when divided by 4 people, your {total_potions} wil become {potioneach} for each person')
# Out:
# when divided by 4 people, your 23 wil become 5 for each person

# %% [markdown]
# ## Quick Recall: Conditionals
#
# `if` / `elif` / `else` runs the first `True` branch and skips the rest. Combine conditions with `and` / `or` / `not`. Remember: `=` assigns, `==` compares.

# %%
# Example
monster_health = 12
if monster_health <= 0:
    print("Defeated.")
elif monster_health < 20:
    print("Nearly there.")
else:
    print("Still tough.")
# Out:
# Nearly there.

# %% [markdown]
# **Quick check:** sort a `trust_level` (0.0–1.0) into "low", "medium", or "high" using your own thresholds, with `if`/`elif`/`else`.

# %%
# Your quick check here
trust = 34

if trust <= 0:
    print("You are not trusted.")
elif trust < 10:
    print('you are a little trusted')
else:
    print("You are trusted.")
# Out:
# You are trusted.
