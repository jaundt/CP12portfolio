# %% [markdown]
# # Project 1A — Character & First Choice
#
# **Checkpoint 1 of 3.** This is where the adventure game actually becomes *your* adventure game — everything from here builds on what you make today. Using only what 1.1–1.4 taught you (variables, input/output, operators, conditionals), you'll create a character and give them one real decision to make.
#
# No new syntax today — this is about putting the last four lessons together into one working thing, which is its own skill.

# %% [markdown]
# ## Requirements
#
# **Tier 1 — Minimum viable:**
# 1. At least four character variables, one of each type (`str`, `int`, `float`, `bool`) — name, a stat, another stat, and something true/false about them
# 2. At least one value read with `input()` (the character's name is a natural fit)
# 3. At least one calculation using an operator (e.g. combining two stats, or computing a starting score)
# 4. An "intro" printed with f-strings, using your character's variables
# 5. **One branching decision** (`if`/`else`) where the player's choice or a stat leads to two genuinely different printed outcomes
#
# **Tier 2 — Aim for this:**
# - Turn the branching decision into `if`/`elif`/`else` for a third possible outcome
# - Base the branch on a comparison (a stat threshold), not just matching a typed word
# - A multi-line intro that actually paints a scene, not just a stat dump
#
# **Tier 3 — Stretch:**
# - Combine two conditions with `and`/`or` for the branch
# - Have the choice change a stat's value afterward (using an operator), so the consequence is visible if you print the character's status again at the end

# %% [markdown]
# ## Starter Scaffold
#
# Below is a skeleton to build from — not a fill-in-the-blank, a starting point. Replace every `# TODO` with your own code; add, remove, or restructure anything you want, as long as the requirements above are met.

# %%
# TODO: define your character's variables — one str, one int, one float, one bool

name = 'jon'
fingers = 3
height = 2.6
lives = True

# TODO: use input() to ask the player for at least one value (e.g. the character's name)

UsVl = input('what is your name?')
name.append(UsVl)
print (name)
# TODO: print an intro for your character using f-strings

# TODO: write your branching decision (if / else, or if / elif / else)
#       — make sure both (or all) branches actually print something different

# %% [markdown]
# ## Before You Commit
#
# Run your notebook top to bottom at least twice, choosing differently each time (or with different input), and confirm you actually see **both** (or all) of your branch's outcomes print correctly — not just the one you tested first.

# %% [markdown]
# ## AI Collaboration Log
#
# If you used AI for any part of this project, log it here before you commit — same habit as your portfolio README:
#
# - What did you ask for?
# - What did you keep, and what did you change?
#
# *(If you didn't use AI this time, just write "Didn't use AI for this one.")*
#
# **Your log:** *(double-click to edit this cell)*
